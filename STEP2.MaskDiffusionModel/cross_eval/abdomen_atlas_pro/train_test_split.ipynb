# %%
import pandas as pd

# %%
df = pd.read_csv("RadiomicsMaskMetricsBadDropped.csv")

# %%
turkish = pd.read_csv("/projects/bodymaps/Data/turkish_dataset_meta_latest.csv")
# Out:
# /local/rpinise1/3817387/ipykernel_2205401/2275081219.py:1: DtypeWarning: Columns (170,171,172,174,176,177,179,180,182,183,184,185,186,187,188,192,193,197,200,201,202,204,208,209,210,211,213,215,218,223,224,227,228,229,231,232,233,237,243,244,247,248,250,254,255,257,258,259,260) have mixed types. Specify dtype option on import or set low_memory=False.
#   turkish = pd.read_csv("/projects/bodymaps/Data/turkish_dataset_meta_latest.csv")

# %%
df = df[df["bdmap_id"].isin(turkish['BDMAP ID'])]

# %%
df.to_csv("RadiomicsMaskMetricsBadDropped_Test.csv",index=False)
