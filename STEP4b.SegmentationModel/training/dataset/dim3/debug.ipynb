# %%
import pandas as pd

# %%
import numpy as np

# %%
x = np.load('/projects/bodymaps/Pedro/data/report_embeddings_clinical_longformer/BDMAP_00032584/adrenal_glands.npy')

# %%
x.shape
# Out:
# (768,)

# %%
x
# Out:
# array([-1.82100177e-01, -2.09314679e-03, -2.74299178e-02,  1.77274823e-01,
#         3.74540448e-01, -1.01849727e-01,  6.18106611e-02,  2.64246315e-01,
#         3.59891988e-02, -1.13453582e-01,  1.61420032e-01,  1.89797789e-01,
#         6.93359375e-02, -8.73736218e-02,  6.61190227e-02, -5.40441155e-01,
#        -1.15751378e-01,  7.43336380e-02, -4.05560657e-02, -3.34099263e-01,
#        -5.53768389e-02,  1.95657164e-01,  2.85357311e-02,  1.34191170e-01,
#         9.34053287e-02, -3.84306051e-02,  2.75045961e-01,  1.53837323e-01,
#        -1.36718750e-01,  6.84742630e-02, -4.51516546e-02,  6.22127764e-02,
#        -2.92107072e-02,  2.66256891e-02,  3.17382812e-02,  4.78228405e-02,
#         1.68887869e-01,  1.11672796e-01,  6.72104806e-02,  4.33134176e-02,
#         7.21507370e-02,  7.63442069e-02,  1.03745401e-01,  2.19439343e-02,
#         8.18014741e-02, -6.77274838e-02, -8.75459537e-02,  6.48767827e-03,
# ...
