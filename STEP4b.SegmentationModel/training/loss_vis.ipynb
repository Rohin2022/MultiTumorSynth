# %%
import sys
sys.path.append('/projects/bodymaps/Pedro/foundational/MedFormer/')
import losses_foundation as lf

# %%
lf.plot_loss('huber',y=1,tolerance=0.1,k=0.5,limit=10)

# %%
import importlib
importlib.reload(lf)
lf.save_ball_kernel(diameter=10, gaussian=True, gaussian_std=1.5, filename='ball.nii.gz')
# Out:
# Center value: 0.0014202119782567024
# Border value: 0.0012443020241335034
# Saved ball kernel to ball.nii.gz

# %%
import importlib
importlib.reload(lf)
lf.generate_input_and_process_volume(square_size=20,gaussian=True,square_location='corner',diameter=20,tumor_volume=800)
# Out:
# Saved input volume to input_volume.nii.gz
# Saved tumor mask to tumor_mask.nii.gz

# %%
import importlib
importlib.reload(lf)
lf.plot_dice_based_volume_loss(y_value=500,cross_entropy=True,x_max=100000,E=500)

# %%
import importlib

import sys
sys.path.append('/projects/bodymaps/Pedro/foundational/MedFormer/')
import losses_foundation as lf


importlib.reload(lf)

lf.plot_dice_based_volume_loss(y_value=1000,cross_entropy=False,x_max=5000,E=500)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
